# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
m = 30
n = 6

data = np.zeros((m, n))

for i in range(n):
    data[:, i] = 30 * np.random.randn(m) * (2 * i / (n - 1) - 1) ** 2 + (i + 1) ** 2

# %%
plt.boxplot(data)
plt.show()

# %%
sns.boxplot(data=data, orient='v')
plt.show()

# %%
df = pd.DataFrame(data)
df.plot(kind='box')

plt.show()

# %%
df = pd.DataFrame(data, columns=['zero', 'one', 'two', 'three', 'four', 'five'])
sns.boxplot(data=df, orient='h')

plt.show()
# Out:
# /home/alllowd/anaconda3/envs/ml_data_science/lib/python3.10/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
N = 1000

data_1 = np.random.randn(N)
data_2 = np.random.rand(N)

data = np.vstack((data_1, data_2)).T

plt.boxplot(np.array([data_1, data_2]).T)
plt.show()
